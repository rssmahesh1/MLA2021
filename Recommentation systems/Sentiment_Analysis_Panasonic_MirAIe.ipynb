# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

def getUrls():
    URL = ["https://www.amazon.in/Panasonic-MirAIe/product-reviews/B083J8JKG3/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&sortBy=recent&pageNumber=1"]
    urllist = URL
    return urllist

# function to get the soup object from the input URL
def getsoup(url):
    response = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
    Status_Code = response.status_code
    # print(url)
    # print(Status_Code)
    
    if Status_Code == 200:
      soup = BeautifulSoup(response.content)
    else:
      soup = getsoup(url)
    return soup  

# function to get the last page number of reviews for a particular product
def getLastPageNumber(soup):
    pageNumber = []
    t = soup.find("div", {"data-hook":"cr-filter-info-review-rating-count"}).text.replace("\n","").strip()
    strWithNos=' '.join(t.split())
    rating_review_count=[int(i) for i in strWithNos.split() if i.isdigit()]
    review_number = rating_review_count[1]
    if review_number <=10:
        lastPage = 1
    else:
        lastPage=round(rating_review_count[1]/10)
    return lastPage

# Function to create a list of URLs for all the review pages for a product
def geturllist(url, lastPage):
    urllistPages = []
    if url.endswith('pageNumber=1'):
      url = url[:-1]
    for i in range(1,lastPage+1):
      urllistPages.append (url + str(i))
    return urllistPages


##Defining a function to extract all the required elements from a product review page
#  #extracting the titles of the reviews
def getReviews(soup, url):   
    title_sec = soup.find_all("a","a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold")
    title = []
    for s in title_sec:
      title.append(s.text.replace('\n',''))
        
#  #extracting the author names of the reviews
    author_sec = soup.find_all("a","a-profile")
    author = []
    for r in author_sec:
      author.append(r.text)

#  #extracting the raw text of the reviews        

    Review_text_sec = soup.find_all("span",'a-size-base review-text review-text-content')
    text = []
    for t in Review_text_sec:
      text.append(t.text.replace('\n', '').lstrip())
    print(text)
    print(len(text))

#  #extracting the rating of the reviews  

    Rating = soup.find_all(attrs={"data-hook": "review-star-rating"})    
    rate = []
    for d in Rating:
      rate.append(d.text)
    # print(rate)

#  #extracting the date of the reviews 

    Date_sec = soup.find_all(attrs={"data-hook": "review-date"})    
    date = []
    for d in Date_sec:
      date.append(d.text) 
    # print(date)
    # print(len(date))

#  #extracting the review was helpful info of the reviews 

    help_sec = soup.find_all(attrs={"data-hook": "review-voting-widget"})    
    help1 = []
    for d in help_sec:
      help1.append(d.text.replace('\n', '').lstrip())
    # print(help1)
    # print(len(help1))
        
    collate_df = pd.DataFrame({'Date':date,
                                        'Review_Title':title,
                                        'Rating':rate,
                                        'Author':author[2:],
                                        'Review_text':text,
                                        'Review_helpful':help1})
    return collate_df

#Sequencing and calling the functions to complete the task

if __name__ == '__main__':
    
    urllist = getUrls()
    df2 = []
    y = 1
    for url in urllist:         
        soup = getsoup(url)
        lastPage = getLastPageNumber(soup)
        urllistPages = geturllist(url, lastPage)
        x = 1
        for url in urllistPages:
            soup = getsoup(url)
            df1 = getReviews(soup, url)  
            print("df1",df1)                  
            if x == 1:
                df3 = []
                df3 = df1
            else:                        
                df2 = df3
                print("type",type(df2))
                result = df2.append(df1, ignore_index=True)
                df3 = result
            x += 1
        df3.to_csv ("Amazon_reviews" + str(y) + ".csv")
        print(df3)
        y += 1
# Out:
# ['not able to connect and activate', 'Some customers here reviewed as  Panasonic MirAie skill is not listed in Amazon Alexa app. I am also facing this problem. I contact the customer care through alexa help section by chatting. They adviced me to change the location. Instead of me she herself changed my location. After that you want to close and reopen the all apps. Now you can see the panasonic MirAie skill. You can control your AC by voice commands by enabling the skill. So it is not the Amazon Alexa issue or panasonic ac manufacturer, It is our mistake.', "I cant set powerful mode in my through alexa. You can name it high cool mode or jet cool mode or turbo mode. But my AC remote named that function as powerful mode. However that doesn't work with alexa", 'skill not working tried everything from reinstalling to changing the device name but everytime it do discover my ac but everytime say my ac is not responding', "Skill Not available on iOS 14.4.2 - Alexa app.Unable to configure. Said it's supported on both ios and android", 'working well for me', 'It took me quite some time to understand that your amazon kindle setting needs to be on amazon.in instead of amazon.com in order to enable this skill.This skill is very elementry and does only basic things, needs a lot of improvement. but still, much easier as compared to finding the remote and controlling the ac', 'Everything is working fine , Except the display on off feature. please add that too.', 'just need one more feature of display off with alexa.', "Not showing up in Skills section in amazon Alexa India. Tried many ways to find the skill but couldn't find."]
# 10
# df1                                  Date  ... Review_helpful
# 0    Reviewed in India on 14 May 2021  ...        Helpful
# 1    Reviewed in India on 10 May 2021  ...        Helpful
# 2     Reviewed in India on 5 May 2021  ...        Helpful
# 3     Reviewed in India on 1 May 2021  ...        Helpful
# 4  Reviewed in India on 23 April 2021  ...        Helpful
# 5  Reviewed in India on 21 April 2021  ...        Helpful
# 6  Reviewed in India on 14 April 2021  ...        Helpful
# 7  Reviewed in India on 14 April 2021  ...        Helpful
# 8   Reviewed in India on 9 April 2021  ...        Helpful
# 9   Reviewed in India on 6 April 2021  ...        Helpful
#
# [10 rows x 6 columns]
# ["The device is unresponsive to any command. Even though it has been linked to the alexa app it doesn't perform any action at all. Not even basic switch on or off.", 'can\'t set timer by voice command with Alexa (echo dot) such as "turn off the AC after an hour). Please add this skill or guide is how to do it.', "Was quite easy to setup for me, and it works like a charm - at least as of the writing of this review (24 March 2021). Of course, you need to follow the proper procedure (using the MirAIe app etc) as explained elsewhere to make it work, but it's not too difficult in my opinion. Now that the skill is all setup, I am able to give Alexa instructions to turn on/off the AC, set the AC temperature, change the AC fan speed. That's all I need and it works just as advertised.", 'Loved it... Alexa....', 'very good product in the Panasonic', "Can't see this skill on Alexa app ver much disappointed I have search in Alexa skills but there was no skill", "Panasonic MirAIe skill isn't showing up in Alexa app! Please fix asap. Alexa control was the sole reason I purchased a Panasonic ac.", 'I could not link my Panasonic smart Ac to Alexa though i have MirAie installed and linked', 'very good app', 'Already had the MirAIe app setup and working, and this smart skill just fits in. The AC gets recognised as a Thermostat and most commands works like a charm.']
# 10
# df1                                     Date  ...                                  Review_helpful
# 0      Reviewed in India on 5 April 2021  ...                                         Helpful
# 1     Reviewed in India on 31 March 2021  ...                                         Helpful
# 2     Reviewed in India on 24 March 2021  ...                                         Helpful
# 3      Reviewed in India on 5 March 2021  ...                                         Helpful
# 4      Reviewed in India on 4 March 2021  ...                                         Helpful
# 5  Reviewed in India on 24 February 2021  ...    2 people found this helpful          Helpful
# 6   Reviewed in India on 8 February 2021  ...   13 people found this helpful          Helpful
# 7    Reviewed in India on 5 January 2021  ...  One person found this helpful          Helpful
# 8  Reviewed in India on 29 November 2020  ...                                         Helpful
# 9  Reviewed in India on 22 November 2020  ...  One person found this helpful          Helpful
#
# [10 rows x 6 columns]
# type <class 'pandas.core.frame.DataFrame'>
# ['This skill is not in search options. I cant find this skill. I think its removed from Alexa list of skills.', 'Its not an easy setup to enable this skill, moreover it can only switch on/ off the AC and temperature control. Most important to setup off/on timer. everytime you ask Alexa set an AC off timer, Alexa starts its own timer...quite funny, but need to make her learn this skill.', 'Not able to find the skill in my Alexa app which is on an IOS-14 iPhone. Need to add this soon.', 'Why does the alexa app allow to switch ac on and off but voice command wont?', 'Cannot find the Alexa skill to enable echo. The MirAIe app is okay, could do with more options like sleep wake up timer etc.Update: I had to call amazon to get the skill enabled on my amazon account, as the skill is only available in amazon india. Panasonic support staff was quite clueless. Call amazon to get It enabled.', 'Not showing on Alexa now.I really like Panasonic brand.But i think its time to move on..They arentvreafy for IoTPoor implementation..', 'How about giving users more control on their ACs.Add a command to control the AC’s display.Add a command to control the AC’s fan speed.Add a command to control jet stream.', 'when I tap log in ... after that a blank screen comes up saying validate the number', 'Seamless integration with alexa. Available only in Indian marketplace though.', 'Create Id(Mobile number) and pwd for Mirale and use the same while giving access to alexa']
# 10
# df1                                      Date  ...                                  Review_helpful
# 0    Reviewed in India on 6 November 2020  ...    2 people found this helpful          Helpful
# 1  Reviewed in India on 29 September 2020  ...    3 people found this helpful          Helpful
# 2  Reviewed in India on 22 September 2020  ...                                         Helpful
# 3     Reviewed in India on 27 August 2020  ...                                         Helpful
# 4      Reviewed in India on 7 August 2020  ...  One person found this helpful          Helpful
# 5      Reviewed in India on 1 August 2020  ...   10 people found this helpful          Helpful
# 6       Reviewed in India on 17 July 2020  ...  One person found this helpful          Helpful
# 7       Reviewed in India on 14 July 2020  ...                                         Helpful
# 8        Reviewed in India on 5 July 2020  ...                                         Helpful
# 9        Reviewed in India on 5 June 2020  ...    2 people found this helpful          Helpful
#
# [10 rows x 6 columns]
# type <class 'pandas.core.frame.DataFrame'>
# ['as expected', 'cannot connect alexa to my ac .says authentication error', 'Great skill...works perfectly fine !', 'Working seamlessly now.', 'Even after registering on their app, alexa skill is not getting enabled! Getting error as Something went wrong during the authentication process.Please try signing in again.Update : tried to connect support with given email miraie.support@in.panasonic.com, email got bounced saying it does not exists!! Is this even authentic Panasonic skill?', 'Not able to connect to alexa device', 'Not able to use this as Im not able to pair this with my alexa device, completely useless.UPDATE - Its working fine now']
# 7
# df1                                  Date  ...                                  Review_helpful
# 0    Reviewed in India on 27 May 2020  ...                                         Helpful
# 1    Reviewed in India on 25 May 2020  ...    2 people found this helpful          Helpful
# 2    Reviewed in India on 17 May 2020  ...  One person found this helpful          Helpful
# 3  Reviewed in India on 21 March 2020  ...                                         Helpful
# 4  Reviewed in India on 20 March 2020  ...    2 people found this helpful          Helpful
# 5  Reviewed in India on 20 March 2020  ...                                         Helpful
# 6  Reviewed in India on 19 March 2020  ...    3 people found this helpful          Helpful
#
# [7 rows x 6 columns]
# type <class 'pandas.core.frame.DataFrame'>
#                                       Date  ...                                  Review_helpful
# 0         Reviewed in India on 14 May 2021  ...                                         Helpful
# 1         Reviewed in India on 10 May 2021  ...                                         Helpful
# 2          Reviewed in India on 5 May 2021  ...                                         Helpful
# 3          Reviewed in India on 1 May 2021  ...                                         Helpful
# 4       Reviewed in India on 23 April 2021  ...                                         Helpful
# 5       Reviewed in India on 21 April 2021  ...                                         Helpful
# 6       Reviewed in India on 14 April 2021  ...                                         Helpful
# 7       Reviewed in India on 14 April 2021  ...                                         Helpful
# 8        Reviewed in India on 9 April 2021  ...                                         Helpful
# 9        Reviewed in India on 6 April 2021  ...                                         Helpful
# 10       Reviewed in India on 5 April 2021  ...                                         Helpful
# 11      Reviewed in India on 31 March 2021  ...                                         Helpful
# 12      Reviewed in India on 24 March 2021  ...                                         Helpful
# 13       Reviewed in India on 5 March 2021  ...                                         Helpful
# 14       Reviewed in India on 4 March 2021  ...                                         Helpful
# 15   Reviewed in India on 24 February 2021  ...    2 people found this helpful          Helpful
# 16    Reviewed in India on 8 February 2021  ...   13 people found this helpful          Helpful
# 17     Reviewed in India on 5 January 2021  ...  One person found this helpful          Helpful
# 18   Reviewed in India on 29 November 2020  ...                                         Helpful
# 19   Reviewed in India on 22 November 2020  ...  One person found this helpful          Helpful
# 20    Reviewed in India on 6 November 2020  ...    2 people found this helpful          Helpful
# 21  Reviewed in India on 29 September 2020  ...    3 people found this helpful          Helpful
# 22  Reviewed in India on 22 September 2020  ...                                         Helpful
# 23     Reviewed in India on 27 August 2020  ...                                         Helpful
# 24      Reviewed in India on 7 August 2020  ...  One person found this helpful          Helpful
# 25      Reviewed in India on 1 August 2020  ...   10 people found this helpful          Helpful
# 26       Reviewed in India on 17 July 2020  ...  One person found this helpful          Helpful
# 27       Reviewed in India on 14 July 2020  ...                                         Helpful
# 28        Reviewed in India on 5 July 2020  ...                                         Helpful
# 29        Reviewed in India on 5 June 2020  ...    2 people found this helpful          Helpful
# 30        Reviewed in India on 27 May 2020  ...                                         Helpful
# 31        Reviewed in India on 25 May 2020  ...    2 people found this helpful          Helpful
# 32        Reviewed in India on 17 May 2020  ...  One person found this helpful          Helpful
# 33      Reviewed in India on 21 March 2020  ...                                         Helpful
# 34      Reviewed in India on 20 March 2020  ...    2 people found this helpful          Helpful
# 35      Reviewed in India on 20 March 2020  ...                                         Helpful
# 36      Reviewed in India on 19 March 2020  ...    3 people found this helpful          Helpful
#
# [37 rows x 6 columns]

# %%
df3.head()
# Out:
#                                  Date  ... Review_helpful
# 0    Reviewed in India on 14 May 2021  ...        Helpful
# 1    Reviewed in India on 10 May 2021  ...        Helpful
# 2     Reviewed in India on 5 May 2021  ...        Helpful
# 3     Reviewed in India on 1 May 2021  ...        Helpful
# 4  Reviewed in India on 23 April 2021  ...        Helpful
#
# [5 rows x 6 columns]

# %%
## Exploratory Data Analysis
df3.Rating.value_counts()
# Out:
# 1    15
# 5    13
# 3     6
# 2     2
# 4     1
# Name: Rating, dtype: int64

# %%
## Replacing the text in the column 'Ratings' to required ratings integer values.
rating_dic={"5.0 out of 5 stars": 5,
                     "4.0 out of 5 stars": 4,
                     "3.0 out of 5 stars": 3,
                     "2.0 out of 5 stars": 2,
                     "1.0 out of 5 stars": 1}
rating_dic                    
df3["Rating"].value_counts()
# Out:
# 1    15
# 5    13
# 3     6
# 2     2
# 4     1
# Name: Rating, dtype: int64

# %%
## Summarizing the data we have
print("Summary statistics of numerical features : \n", df3.describe())
print("\nTotal number of reviews: ",len(df3))
print("\nPercentage of reviews with neutral sentiment : {:.2f}%".format(df3[df3['Rating']==3]["Review_text"].count()/len(df3)*100))
print("\nPercentage of reviews with positive sentiment : {:.2f}%".format(df3[df3['Rating']>3]["Review_text"].count()/len(df3)*100))
print("\nPercentage of reviews with negative sentiment : {:.2f}%".format(df3[df3['Rating']<3]["Review_text"].count()/len(df3)*100))
# Out:
# Summary statistics of numerical features :
#            Rating
# count  37.000000
# mean    2.864865
# std     1.782043
# min     1.000000
# 25%     1.000000
# 50%     3.000000
# 75%     5.000000
# max     5.000000
#
# Total number of reviews:  37
#
# Percentage of reviews with neutral sentiment : 16.22%
#
# Percentage of reviews with positive sentiment : 37.84%
#
# Percentage of reviews with negative sentiment : 45.95%

# %%
# Plotting distribution of rating
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
df3['Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Plotting distribution of review length
review_length = df3["Review_text"].dropna().map(lambda x: len(x))
plt.figure(figsize=(12,8))
review_length.loc[review_length < 1500].hist()
plt.title("Distribution of Review Length")
plt.xlabel('Review length (Number of character)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import numpy as np
# Dropping missing values
df3.dropna(inplace=True)

# Considering reviews with positive sentiment (rating = 4, 5) and negative sentiment (rating = 1, 2)
# and dropping reviews with neutral sentiment (rating 3).
df3 = df3[df3['Rating'] != 3]

# Encoding 4s and 5s as 1 (positive sentiment) and 1s and 2s as 0 (negative sentiment)
df3['Sentiment'] = np.where(df3['Rating'] > 3, 1, 0)
df3.head()
print(df3)
# Out:
#                                       Date  ... Sentiment
# 0         Reviewed in India on 14 May 2021  ...         0
# 3          Reviewed in India on 1 May 2021  ...         0
# 4       Reviewed in India on 23 April 2021  ...         0
# 5       Reviewed in India on 21 April 2021  ...         1
# 7       Reviewed in India on 14 April 2021  ...         1
# 9        Reviewed in India on 6 April 2021  ...         0
# 10       Reviewed in India on 5 April 2021  ...         0
# 12      Reviewed in India on 24 March 2021  ...         1
# 13       Reviewed in India on 5 March 2021  ...         1
# 14       Reviewed in India on 4 March 2021  ...         1
# 15   Reviewed in India on 24 February 2021  ...         0
# 16    Reviewed in India on 8 February 2021  ...         0
# 17     Reviewed in India on 5 January 2021  ...         0
# 18   Reviewed in India on 29 November 2020  ...         1
# 19   Reviewed in India on 22 November 2020  ...         1
# 20    Reviewed in India on 6 November 2020  ...         0
# 22  Reviewed in India on 22 September 2020  ...         0
# 23     Reviewed in India on 27 August 2020  ...         0
# 24      Reviewed in India on 7 August 2020  ...         0
# 25      Reviewed in India on 1 August 2020  ...         0
# 26       Reviewed in India on 17 July 2020  ...         1
# 27       Reviewed in India on 14 July 2020  ...         0
# 28        Reviewed in India on 5 July 2020  ...         1
# 29        Reviewed in India on 5 June 2020  ...         1
# 30        Reviewed in India on 27 May 2020  ...         1
# 31        Reviewed in India on 25 May 2020  ...         0
# 32        Reviewed in India on 17 May 2020  ...         1
# 33      Reviewed in India on 21 March 2020  ...         1
# 34      Reviewed in India on 20 March 2020  ...         0
# 35      Reviewed in India on 20 March 2020  ...         0
# 36      Reviewed in India on 19 March 2020  ...         1
#
# [31 rows x 7 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Spliting data into training set and validation
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.pipeline import Pipeline
import re

X_train, X_test, y_train, y_test = train_test_split(df3['Review_text'], df3['Sentiment'], test_size=0.3, random_state=0)

print('Loading %d training examples and %d validation examples. \n' %(X_train.shape[0],X_test.shape[0]))
# Out:
# Loading 21 training examples and 10 validation examples.

# %%
# Creating a function to do text preprocessing
import nltk
nltk.download('stopwords')

def cleanText(raw_text, remove_stopwords=False, stemming=False, split_text=False):
    
    #removing html
    text = BeautifulSoup(raw_text, 'lxml').get_text() 
    
    # Removing non-character
    letters_only = re.sub("[^a-zA-Z]", " ", text)
    
    # converting to lower case
    words = letters_only.lower().split()  
    
    # Removing stopword
    if remove_stopwords: 
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    
    # Stemming
    if stemming==True: 
        stemmer = SnowballStemmer('english') 
        words = [stemmer.stem(w) for w in words]
        print(words)

    # Spliting text    
    if split_text==True:  
        return (words)
    
    return( " ".join(words))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Preprocessing text data in training set and validation set

X_train_cleaned = []
X_test_cleaned = []

for d in X_train:
    X_train_cleaned.append(cleanText(d))
print('Showing a cleaned review in the training set : \n\n',  X_train_cleaned[1])
    
for d in X_test:
    X_test_cleaned.append(cleanText(d))
# Out:
# Showing a cleaned review in the training set :
#
#  not able to find the skill in my alexa app which is on an ios iphone need to add this soon

# %%
# Splitting  review text into parsed sentences uisng NLTK's punkt tokenizer
import nltk
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize, pos_tag

import logging
from gensim.models import word2vec
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from keras.layers.embeddings import Embedding

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

def parseSent(review, tokenizer, remove_stopwords=False):
    #Parse text into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(cleanText(raw_sentence, remove_stopwords, split_text=True))
    return sentences


# Parsing each review in the training set into sentences
sentences = []
for review in X_train_cleaned:
    sentences += parseSent(review, tokenizer)
    
print('%d parsed sentence in the training set\n'  %len(sentences))
print('Show a parsed sentence in the training set : \n',  sentences[10])
# Out:
# 21 parsed sentence in the training set
#
# Show a parsed sentence in the training set :
#  ['cannot', 'find', 'the', 'alexa', 'skill', 'to', 'enable', 'echo', 'the', 'miraie', 'app', 'is', 'okay', 'could', 'do', 'with', 'more', 'options', 'like', 'sleep', 'wake', 'up', 'timer', 'etc', 'update', 'i', 'had', 'to', 'call', 'amazon', 'to', 'get', 'the', 'skill', 'enabled', 'on', 'my', 'amazon', 'account', 'as', 'the', 'skill', 'is', 'only', 'available', 'in', 'amazon', 'india', 'panasonic', 'support', 'staff', 'was', 'quite', 'clueless', 'call', 'amazon', 'to', 'get', 'it', 'enabled']

# %%
# Fitting parsed sentences to Word2Vec model 

num_features = 300                    
min_word_count = 10                
num_workers = 4       
context = 10                                                                                          
downsampling = 1e-3 

print("Training Word2Vec model ...\n")
w2v = Word2Vec(sentences, workers=num_workers, size=num_features, min_count = min_word_count,\
                 window = context, sample = downsampling)
w2v.init_sims(replace=True)
w2v.save("w2v_300features_10minwordcounts_10context")

print("Number of words in the vocabulary list : %d \n" %len(w2v.wv.index2word))
print("Show first 10 words in the vocalbulary list  vocabulary list: \n", w2v.wv.index2word[0:10])
# Out:
# Training Word2Vec model ...
#
# Number of words in the vocabulary list : 9
#
# Show first 10 words in the vocalbulary list  vocabulary list:
#  ['to', 'the', 'not', 'skill', 'in', 'alexa', 'is', 'it', 'i']

# %%
# Transfroming the training data into feature vectors

def makeFeatureVec(review, model, num_features):
   
    featureVec = np.zeros((num_features,),dtype="float32")
    nwords = 0.
    index2word_set = set(model.wv.index2word) #index2word is the volcabulary list of the Word2Vec model
    isZeroVec = True
    for word in review:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec, model[word])
            isZeroVec = False
    if isZeroVec == False:
        featureVec = np.divide(featureVec, nwords)
    return featureVec


def getAvgFeatureVecs(reviews, model, num_features):
    
    counter = 0
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    for review in reviews:
        reviewFeatureVecs[counter] = makeFeatureVec(review, model,num_features)
        counter = counter + 1
    return reviewFeatureVecs

# %%
# Getting feature vectors for training set
X_train_cleaned = []
for review in X_train:
    X_train_cleaned.append(cleanText(review, remove_stopwords=True, split_text=True))
trainVector = getAvgFeatureVecs(X_train_cleaned, w2v, num_features)
print("Training set : %d feature vectors with %d dimensions" %trainVector.shape)


# Getting feature vectors for validation set
X_test_cleaned = []
for review in X_test:
    X_test_cleaned.append(cleanText(review, remove_stopwords=True, split_text=True))
testVector = getAvgFeatureVecs(X_test_cleaned, w2v, num_features)
print("Validation set : %d feature vectors with %d dimensions" %testVector.shape)
# Out:
# Training set : 21 feature vectors with 300 dimensions
# Validation set : 10 feature vectors with 300 dimensions
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':

# %%
# Defining a function check the Model Evalutaion Metrices
def modelEvaluation(predictions):
    
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test, predictions)))
    print("\nAUC score : {:.4f}".format(roc_auc_score(y_test, predictions)))
    print("\nClassification report : \n", metrics.classification_report(y_test, predictions))
    print("\nConfusion Matrix : \n", metrics.confusion_matrix(y_test, predictions))

# %%
# Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(trainVector, y_train)
predictions = rf.predict(testVector)
modelEvaluation(predictions)
print(df3)
# Out:
# Accuracy on validation set: 0.8000
#
# AUC score : 0.7500
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.80        10
#    macro avg       0.88      0.75      0.76        10
# weighted avg       0.85      0.80      0.78        10
#
#
# Confusion Matrix :
#  [[6 0]
#  [2 2]]
#                                       Date  ... Sentiment
# 0         Reviewed in India on 14 May 2021  ...         0
# 3          Reviewed in India on 1 May 2021  ...         0
# 4       Reviewed in India on 23 April 2021  ...         0
# 5       Reviewed in India on 21 April 2021  ...         1
# 7       Reviewed in India on 14 April 2021  ...         1
# 9        Reviewed in India on 6 April 2021  ...         0
# 10       Reviewed in India on 5 April 2021  ...         0
# 12      Reviewed in India on 24 March 2021  ...         1
# 13       Reviewed in India on 5 March 2021  ...         1
# 14       Reviewed in India on 4 March 2021  ...         1
# 15   Reviewed in India on 24 February 2021  ...         0
# 16    Reviewed in India on 8 February 2021  ...         0
# 17     Reviewed in India on 5 January 2021  ...         0
# 18   Reviewed in India on 29 November 2020  ...         1
# 19   Reviewed in India on 22 November 2020  ...         1
# 20    Reviewed in India on 6 November 2020  ...         0
# 22  Reviewed in India on 22 September 2020  ...         0
# 23     Reviewed in India on 27 August 2020  ...         0
# 24      Reviewed in India on 7 August 2020  ...         0
# 25      Reviewed in India on 1 August 2020  ...         0
# 26       Reviewed in India on 17 July 2020  ...         1
# 27       Reviewed in India on 14 July 2020  ...         0
# 28        Reviewed in India on 5 July 2020  ...         1
# 29        Reviewed in India on 5 June 2020  ...         1
# 30        Reviewed in India on 27 May 2020  ...         1
# 31        Reviewed in India on 25 May 2020  ...         0
# 32        Reviewed in India on 17 May 2020  ...         1
# 33      Reviewed in India on 21 March 2020  ...         1
# 34      Reviewed in India on 20 March 2020  ...         0
# 35      Reviewed in India on 20 March 2020  ...         0
# 36      Reviewed in India on 19 March 2020  ...         1
#
# [31 rows x 7 columns]

# %%
#word cloud for the sentiments
from wordcloud import WordCloud
def create_word_cloud(df3,sentiment):
    try: 
        #df_brand = df.loc[df['Brand'].isin([brand])]
        #df_brand_sample = df_brand.sample(frac=0.1)
        word_cloud_collection = ''
        
        if sentiment == 1:
            df_reviews = df3[df3["Sentiment"]==1]["Review_text"]
        if sentiment == 0:
            df_reviews = df3[df3["Sentiment"]==0]["Review_text"]
            
        for val in df_reviews.str.lower():
            tokens = nltk.word_tokenize(val)
            tokens = [word for word in tokens if word not in stopwords.words('english')]
            for words in tokens:
                word_cloud_collection = word_cloud_collection + words + ' '

        wordcloud = WordCloud(max_font_size=50, width=500, height=300).generate(word_cloud_collection)
        plt.figure(figsize=(20,20))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()
    except: 
        pass

# %%
create_word_cloud(df3,sentiment=1)

# %%
create_word_cloud(df3,sentiment=0)
